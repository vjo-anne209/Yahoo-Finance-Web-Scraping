# %%
import rpa

# %%
rpa.init()
# Out:
# True

# %%
rpa.url('https://sg.finance.yahoo.com/')
# Out:
# True

# %%
search_term = "APPLE"
rpa.type('//*[@id="yfin-usr-qry"]', f'{search_term}[enter]')
# Out:
# True

# %%
url = rpa.read('//*[@class="IbBox Fw(500) fin-tab-item H(44px) desktop_Bgc($hoverBgColor):h desktop-lite_Bgc($hoverBgColor):h  selected "]/a/@href')

# %%
rpa.url("https://sg.finance.yahoo.com"+ url)
# Out:
# True

# %%
head = rpa.read('(//*[@class="W(100%) M(0)"]//tr[1])')
head
# Out:
# 'DateOpenHighLowClose*Adj. close**Volume'

# %%
rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[1]/td[1])')
# Out:
# '15 Sep 2021'

# %%
total = rpa.count('(//*[@class="W(100%) M(0)"]//tbody/tr)')
body = [rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody/tr[{i}])') for i in range(1, total+1)] #check the list
body
# Out:
# ['15 Sep 2021148.56149.09146.37148.10148.1045,191,576',
#  '14 Sep 2021150.35151.07146.91148.12148.12109,170,200',
#  '13 Sep 2021150.63151.42148.75149.55149.55102,404,300',
#  '10 Sep 2021155.00155.48148.70148.97148.97140,646,400',
#  '09 Sep 2021155.49156.11153.95154.07154.0757,305,700',
#  '08 Sep 2021156.98157.04153.98155.11155.1174,420,200',
#  '07 Sep 2021154.97157.26154.39156.69156.6982,278,300',
#  '03 Sep 2021153.76154.63153.09154.30154.3057,808,700',
#  '02 Sep 2021153.87154.72152.40153.65153.6571,115,500',
#  '01 Sep 2021152.83154.98152.34152.51152.5180,313,700',
#  '31 Aug 2021152.66152.80151.29151.83151.8386,453,100',
#  '30 Aug 2021149.00153.49148.61153.12153.1290,956,700',
#  '27 Aug 2021147.48148.75146.83148.60148.6055,721,500',
#  '26 Aug 2021148.35149.12147.51147.54147.5448,597,200',
#  '25 Aug 2021149.81150.32147.80148.36148.3658,991,300',
#  '24 Aug 2021149.45150.86149.15149.62149.6248,606,400',
#  '23 Aug 2021148.31150.19147.89149.71149.7160,131,800',
# ...

# %%
import schedule
import time

def getHistory():
    rpa.url('https://sg.finance.yahoo.com/')
    search_term = "APPLE"
    rpa.type('//*[@id="yfin-usr-qry"]', f'{search_term}[enter]') #search Apple
    #getting url for history tab
    url = rpa.read('//*[@class="IbBox Fw(500) fin-tab-item H(44px) desktop_Bgc($hoverBgColor):h desktop-lite_Bgc($hoverBgColor):h  selected "]/a/@href')
    rpa.url("https://sg.finance.yahoo.com"+ url) #append https...
    total = rpa.count('(//*[@class="W(100%) M(0)"]//tbody/tr)') #count number of rows
    Date = []
    Open = []
    High = []
    Low = []
    Close = []
    Adj_Close = []
    Volume = []
    for row in range(1, total + 1):
        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[1])'):
            Date.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[1])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[2])'):
            Open.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[2])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[3])'):
            High.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[3])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[4])'):
            Low.append(rpa.read(f'//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[4])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[5]'):
            Close.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[5])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[6])'):
            Adj_Close.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[6])'))

        while not rpa.exist(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[7])'):
            Volume.append(rpa.read(f'(//*[@class="W(100%) M(0)"]//tbody//tr[{row}]/td[7])'))
            

schedule.every().hour.do(job)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
# Out:
# False
